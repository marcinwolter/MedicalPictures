# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MedicalPictures/blob/master/figure_cnn_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
#
# Data
title = 7*[0]
titleTab = 7*[0]
extrap = 7*[0]
acc = [[0]*3 for i in range(7)]

size = 7*[0]
compr = 7*[0]



#JPEG NEAREST
#plot  0.5 [97, 80, 32, 15, 7, 3] [77.4399995803833, 77.74999737739563, 75.4800021648407, 78.31000089645386, 79.00000214576721, 75.41999816894531]
#plot  1.0 [97, 80, 32, 15, 7, 3] [89.16000127792358, 90.47999978065491, 89.49000239372253, 88.49999904632568, 86.80999875068665, 82.38999843597412]
#plot  2.0 [97, 80, 32, 15, 7, 3] [91.21000170707703, 90.89999794960022, 89.99999761581421, 88.1600022315979, 87.08000183105469, 81.7900002002716]
#[255.26074609375, 128.1747890625, 64.047759765625, 32.684560546875, 16.572212890625, 7.374998046875]

title[1] = "JPEG COMPRESSION & NEAREST NEIGHBOUR INTERPOLATION"
titleTab[1] = "nearest"
extrap[1] = [0.5, 1.0, 2.0]
acc[1][0] = [77.4399995803833, 77.74999737739563, 75.4800021648407, 78.31000089645386, 79.00000214576721, 75.41999816894531]
acc[1][1] = [89.16000127792358, 90.47999978065491, 89.49000239372253, 88.49999904632568, 86.80999875068665, 82.38999843597412]
acc[1][2] = [91.21000170707703, 90.89999794960022, 89.99999761581421, 88.1600022315979, 87.08000183105469, 81.7900002002716]
size[1]   = [255.26074609375, 128.1747890625, 64.047759765625, 32.684560546875, 16.572212890625, 7.374998046875]
compr[1]  = [97, 80, 32, 15, 7, 3]

#JPEG BILINEAR
#plot  0.5 [97, 80, 32, 15, 7, 3] [86.2500011920929, 86.68000102043152, 86.8399977684021, 86.15000247955322, 84.82999801635742, 80.9000015258789]
#plot  1.0 [97, 80, 32, 15, 7, 3] [88.9299988746643, 89.62000012397766, 89.42000269889832, 87.8000020980835, 86.68000102043152, 81.58000111579895]
#plot  2.0 [97, 80, 32, 15, 7, 3] [89.42999839782715, 89.6399974822998, 89.09000158309937, 88.37000131607056, 86.00000143051147, 81.16999864578247]
#[255.030123046875, 128.229462890625, 64.29569140625, 32.871138671875, 16.436181640625, 7.43928125]

title[2] = "JPEG COMPRESSION & BILINEAR INTERPOLATION"
titleTab[2] = "bilinear"
extrap[2] = [0.5, 1.0, 2.0]
acc[2][0] = [86.2500011920929, 86.68000102043152, 86.8399977684021, 86.15000247955322, 84.82999801635742, 80.9000015258789]
acc[2][1] = [88.9299988746643, 89.62000012397766, 89.42000269889832, 87.8000020980835, 86.68000102043152, 81.58000111579895]
acc[2][2] = [89.42999839782715, 89.6399974822998, 89.09000158309937, 88.37000131607056, 86.00000143051147, 81.16999864578247]
size[2]   = [255.030123046875, 128.229462890625, 64.29569140625, 32.871138671875, 16.436181640625, 7.43928125]
compr[2]  = [97, 80, 32, 15, 7, 3]

#JPEG BICUBIC
#plot  0.5 [97, 80, 32, 15, 7, 3] [86.14000082015991, 86.55999898910522, 86.58999800682068, 86.10000014305115, 85.36999821662903, 80.97000122070312]
#plot  1.0 [97, 80, 32, 15, 7, 3] [88.98000121116638, 89.80000019073486, 89.46999907493591, 88.66000175476074, 86.89000010490417, 82.33000040054321]
#plot  2.0 [97, 80, 32, 15, 7, 3] [90.14999866485596, 90.4699981212616, 89.64999914169312, 88.83000016212463, 87.44000196456909, 81.74999952316284]
#[255.00224609375, 128.1078125, 64.20869140625, 32.8396484375, 16.36240234375, 7.35478515625]

title[3] = "JPEG COMPRESSION & BICUBIC INTERPOLATION"
titleTab[3] = "bicubic"
extrap[3] = [0.5, 1.0, 2.0]
acc[3][0] = [86.14000082015991, 86.55999898910522, 86.58999800682068, 86.10000014305115, 85.36999821662903, 80.97000122070312]
acc[3][1] = [88.98000121116638, 89.80000019073486, 89.46999907493591, 88.66000175476074, 86.89000010490417, 82.33000040054321]
acc[3][2] = [90.14999866485596, 90.4699981212616, 89.64999914169312, 88.83000016212463, 87.44000196456909, 81.74999952316284]
size[3]   = [255.00224609375, 128.1078125, 64.20869140625, 32.8396484375, 16.36240234375, 7.35478515625]
compr[3]  = [97, 80, 32, 15, 7, 3]


#JPEG2000 NEAREST
#plot  0.5 [[1], [2], [4], [8], [16], [32]] [77.7, 76.55999999999999, 73.16, 70.77, 70.37, 70.86]
#plot  1.0 [[1], [2], [4], [8], [16], [32]] [90.13, 89.7, 75.16000000000001, 71.92, 72.92, 71.35000000000001]
#plot  2.0 [[1], [2], [4], [8], [16], [32]] [90.21000000000001, 89.63, 74.52, 71.87, 73.18, 72.47]
#[253.369498046875, 127.84836328125, 63.96396875, 31.6975703125, 15.832939453125, 7.934396484375]

title[4] = "JPEG2000 COMPRESSION & NEAREST NEIGHBOUR INTERPOLATION"
titleTab[4] = "nearest"
extrap[4] = [0.5, 1.0, 2.0]
acc[4][0] = [77.7, 76.55999999999999, 73.16, 70.77, 70.37, 70.86]
acc[4][1] = [90.13, 89.7, 75.16000000000001, 71.92, 72.92, 71.35000000000001]
acc[4][2] = [90.21000000000001, 89.63, 74.52, 71.87, 73.18, 72.47]
size[4]   = [253.369498046875, 127.84836328125, 63.96396875, 31.6975703125, 15.832939453125, 7.934396484375]
compr[4]  = [1, 2, 4, 8, 16, 32]

#JPEG2000 BILINEAR
#plot  0.5 [[1], [2], [4], [8], [16], [32]] [86.05000000000001, 86.00999999999999, 74.33, 71.95, 71.1, 71.47]
#plot  1.0 [[1], [2], [4], [8], [16], [32]] [88.44999999999999, 88.86, 74.78, 72.06, 72.05, 73.15]
#plot  2.0 [[1], [2], [4], [8], [16], [32]] [88.84, 88.4, 74.21, 71.39, 71.67, 71.04]
#[253.30125, 127.816240234375, 63.96433984375, 31.794677734375, 15.89993359375, 7.922193359375]

title[5] = "JPEG2000 COMPRESSION & BILINEAR INTERPOLATION"
titleTab[5] = "bilinear"
extrap[5] = [0.5, 1.0, 2.0]
acc[5][0] = [86.05000000000001, 86.00999999999999, 74.33, 71.95, 71.1, 71.47]
acc[5][1] = [88.44999999999999, 88.86, 74.78, 72.06, 72.05, 73.15]
acc[5][2] = [88.84, 88.4, 74.21, 71.39, 71.67, 71.04]
size[5]   = [253.30125, 127.816240234375, 63.96433984375, 31.794677734375, 15.89993359375, 7.922193359375]
compr[5]  = [1, 2, 4, 8, 16, 32]

#JPEG2000 BICUBIC
#plot  0.5 [[1], [2], [4], [8], [16], [32]] [86.17, 86.29, 74.47, 71.46000000000001, 71.78, 70.73]
#plot  1.0 [[1], [2], [4], [8], [16], [32]] [89.61, 88.88000000000001, 74.58, 72.64, 71.73, 72.02]
#plot  2.0 [[1], [2], [4], [8], [16], [32]] [88.87, 88.85, 74.97, 72.85000000000001, 70.98, 71.05]
#[253.046484375, 127.893359375, 63.9646484375, 31.81142578125, 15.92373046875, 7.791796875]

title[6] = "JPEG2000 COMPRESSION & BICUBIC INTERPOLATION"
titleTab[6] = "bicubic"
extrap[6] = [0.5, 1.0, 2.0]
acc[6][0] = [86.17, 86.29, 74.47, 71.46000000000001, 71.78, 70.73]
acc[6][1] = [89.61, 88.88000000000001, 74.58, 72.64, 71.73, 72.02]
acc[6][2] = [88.87, 88.85, 74.97, 72.85000000000001, 70.98, 71.05]
size[6]   = [253.046484375, 127.893359375, 63.9646484375, 31.81142578125, 15.92373046875, 7.791796875]
compr[6]  = [1, 2, 4, 8, 16, 32]

# %%
#plot accuracy
import matplotlib.pyplot as plt
import matplotlib.pylab as pyl
import numpy as np

! mkdir plots

col = ['green','red','blue']
style = [':','-','--'] #['-','--',':']

for n in range(1,7):

  fig = pyl.figure(figsize=(8,5))

  for k in range(0,3):
    #print(size)
    line, = pyl.plot(np.divide(size[n],size[n][0]/100.), acc[n][k], style[k], color=col[k])
    pyl.plot(np.divide(size[n],size[n][0]/100.), acc[n][k],"o", color='black')
     
    label = "Scaling factor = "+str(extrap[n][k])
    line.set_label(label)

  pyl.legend() 
  pyl.title(title[n])
  pyl.xlabel("IMAGE FILE SIZE [% OF ORIGINAL SIZE]")
  pyl.ylabel("CNN ACCURACY")
  

  auxName = "plots/acc_"+str(n)+".png"
  pyl.savefig(auxName)

  pyl.show()

! zip -r plots.zip plots
# Out:
# mkdir: cannot create directory ‘plots’: File exists
# updating: plots/ (stored 0%)
# updating: plots/acc_5.png (deflated 6%)
# updating: plots/acc_4.png (deflated 7%)
# updating: plots/acc_3.png (deflated 6%)
# updating: plots/acc_6.png (deflated 6%)
# updating: plots/acc_1.png (deflated 6%)
# updating: plots/acc_2.png (deflated 6%)

# %% [markdown]
# # New Section

# %%
#print accuracy

print('\\begin{tabular}{|c|c|cccccc|} ')


print('\\hline ')
print(' &  & \multicolumn{6}{c|}{\\bf File size (\\% of original size)} \\\\')
#print('\\hline ')
print(" &  & ", end =" ")
auxList = ["%.1f"%f for f in np.divide(size[n],size[n][0]/100.) ]
print(*auxList, sep = "\% & ", end =" ")
print('\% \\\\')
print('\\hline ')
print('{\\bf interpolation}  & {\\bf scaling}  &', end=' ')
print('\\multicolumn{6}{c|}{\\bf CNN accuracy} \\\\')
print('{\\bf method} & {\\bf factor} &', end=' ')
print('\\multicolumn{6}{c|}{} \\\\')
print('\\hline ')


for n in range(1,7):
  if n==1:
    print('\\multicolumn{8}{|l|}{\\bf JPEG compression algorithm} \\\\')
    print('\\hline')
  if n==4:
    print('\\hline ')
    print('\\multicolumn{8}{|l|}{\\bf JPEG2000 compression algorithm} \\\\')
    print('\\hline')
  for k in range(0,3):
    print(titleTab[n]+" & "+str(extrap[n][k])+" & ", end =" ")
    auxList = ["%.1f"%f for f in acc[n][k] ]
    print(*auxList, sep = "\% & ", end =" ") 
    print('\% \\\\')

print('\\hline')	
print('\\end{tabular}')
# Out:
# \begin{tabular}{|c|c|cccccc|}
# \hline
#  &  & \multicolumn{6}{c|}{\bf File size (\% of original size)} \\
#  &  &  100.0\% & 50.5\% & 25.3\% & 12.6\% & 6.3\% & 3.1 \% \\
# \hline
# {\bf interpolation}  & {\bf scaling}  & \multicolumn{6}{c|}{\bf CNN accuracy} \\
# {\bf method} & {\bf factor} & \multicolumn{6}{c|}{} \\
# \hline
# \multicolumn{8}{|l|}{\bf JPEG compression algorithm} \\
# \hline
# nearest & 0.5 &  77.4\% & 77.7\% & 75.5\% & 78.3\% & 79.0\% & 75.4 \% \\
# nearest & 1.0 &  89.2\% & 90.5\% & 89.5\% & 88.5\% & 86.8\% & 82.4 \% \\
# nearest & 2.0 &  91.2\% & 90.9\% & 90.0\% & 88.2\% & 87.1\% & 81.8 \% \\
# bilinear & 0.5 &  86.3\% & 86.7\% & 86.8\% & 86.2\% & 84.8\% & 80.9 \% \\
# bilinear & 1.0 &  88.9\% & 89.6\% & 89.4\% & 87.8\% & 86.7\% & 81.6 \% \\
# bilinear & 2.0 &  89.4\% & 89.6\% & 89.1\% & 88.4\% & 86.0\% & 81.2 \% \\
# bicubic & 0.5 &  86.1\% & 86.6\% & 86.6\% & 86.1\% & 85.4\% & 81.0 \% \\
# ...
