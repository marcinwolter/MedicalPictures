# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MedicalPictures/blob/master/figure_jpeg_cnn_reco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code generating geometrical figures and performing pattern recognition using Deep NN
#
# *Feb. 2020, Marcin Wolter*

# %%
'''Trains a simple convnet on the generated set of figures (circle, triangle, square)
'''
from __future__ import print_function

#install KERAS if not there
# !pip install keras_sequential_ascii

import matplotlib.pyplot as plt
import matplotlib.pylab as pyl
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Reshape
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation
from keras import backend as K
from keras_sequential_ascii import sequential_model_to_ascii_printout
from keras.utils import plot_model
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.constraints import maxnorm
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras import metrics

from PIL import Image, ImageDraw

import time
import math
# Out:
# Requirement already satisfied: keras_sequential_ascii in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras_sequential_ascii) (2.2.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.17.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (2.8.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.4.1)
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Prevent Google Colab from disconnecting

# %%
from IPython.display import display, HTML
js = ('<script>function ConnectButton(){ '
           'console.log("Connect pushed"); '
           'document.querySelector("#connect").click()} '
           'setInterval(ConnectButton,3000);</script>')
display(HTML(js))
# Out:
# <script>function ConnectButton(){ console.log("Connect pushed"); document.querySelector("#connect").click()} setInterval(ConnectButton,3000);</script>

# %% [markdown]
# # **Setup the parameters**

# %%
# DNN parameters
batch_size = 128
# number of classes
num_classes = 2
epochs = 256 #12

np.random.seed(2348)

#batch_size_gen = 60000
#batch_size_val = 10000
batch_size_gen = 60000
batch_size_val = 10000

# input image dimensions
img_rows, img_cols = 32, 32
img_shape = (img_rows, img_cols)


#probability of noise and its max. brithness 
prob_noise = 1.0
ampl_noise = 0.3


# figure min and max brithness
fig_min_gray=0.4
fig_max_gray=0.9

#figure sizes
# circle radius
rmin = 0.06
rmax = 0.15
# triangle/rectangle size
dmin = 0.10
dmax = 0.30
# colon / line dot radius in pixels
rpix_min = 0.5
rpix_max = 3

# distortion type
###distortion = "blur"
distortion = "jpeg"
# jpeg_format: jpeg / JPEG2000   - WARNING:  JPEG 2000 does not work on Kaggle!!!!
jpeg_format = "jpeg"
#jpeg_format = 'JPEG2000'
#jpeg_format="jpx"
# distortion - bluring sigma
sigma = (1.8,1.8)
#jpeg compression
jpeg_compression_list = [100,90,70,50,30,10,5,1]   
jpeg2000_compression_list = [[1],[2],[4],[8],[16],[32],[64]] 


# extrapolate True/False
extrapolate = True
# list of extrapolation factors
extrapolation_list = [0.50, 1., 2.]

# Generated 32x32 small image is pasted on a big image, which is a subject of
# graphical operations (jpeg compression, scaling etc). Then it is cropped out
# of it. The big image size is defined here:
bigIm_shape = (512, 512)
smallIm_X = 240
smallIm_Y = 240
# number of images to test the size
n_big = 100

#Remove the saved DNN
! rm best_model.h5
# Out:
# rm: cannot remove 'best_model.h5': No such file or directory

# %% [markdown]
# # **Generate noise**

# %%
def gen_noise(batch_size_gen=batch_size_gen, img_shape=img_shape, prob_noise=prob_noise):

        batch_events = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        for n in range(batch_size_gen):

            for i in range(img_shape[0]):
               for j in range(img_shape[1]):
                 if np.random.random()<prob_noise:
                     batch_events[n,0,i,j]= min(1.,max(0.,ampl_noise*np.random.randn()))


        yield batch_events

# %% [markdown]
# #  Generate geometrical figures - circle, triangle, square, colon, line

# %%
### generate geometrical figures

def generate_circle(r, x0, y0, img_shape):
    """
    Generate a single circle.
    Parameters:
        r: radius
        x0,y0: position of the circle center
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('L', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.ellipse((x0-r, y0-r, x0+r, y0+r), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image)/255
    
    #print(x)
    return x

# %%
def generate_square(d, x0, y0, angle, img_shape):
    """
    Generate a square.
    Parameters:
        d: size
        x0,y0: position of the square center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('L', img_shape) #create new image, 32x32 pixels, 8 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.rectangle((x0-d/2, y0-d/2, x0+d/2, y0+d/2), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image)/255

      
    #print(x)
    return x

# %%
def generate_triangle(d, x0, y0, angle, img_shape):
    """
    Generate a triangle.
    Parameters:
        d: size 
        x0,y0: position of the triangle center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('L', img_shape) #create new image, 32x32 pixels, 8 bit per pixel grayscale
    draw = ImageDraw.Draw(image)
    dd = d/math.sqrt(3)
    draw.polygon(((x0-d/2, y0-dd/2), (x0+d/2, y0-dd/2), (x0,y0+dd)), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image)/255.
    
    #print(x)
    return x

# %%
def generate_line(r, x0, y0, angle, img_shape):
    """
    Generate a line.
    Parameters:
        r: width, length = 5*r
        x0,y0: position of the line center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('L', img_shape) #create new image, 32x32 pixels, 8 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.rectangle((x0-2.5*r, y0-r, x0+2.5*r, y0+r), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image)/255

      
    #print(x)
    return x

# %%
def generate_colon(r, x0, y0, angle, img_shape):
    """
    Generate a colon.
    Parameters:
        r: dot radius
        x0,y0: position of the colon center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('L', img_shape) #create new image, 32x32 pixels, 8 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.ellipse((x0-1.5*r-r, y0-r, x0-1.5*r+r, y0+r), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    draw.ellipse((x0+1.5*r-r, y0-r, x0+1.5*r+r, y0+r), fill = np.random.randint(int(255*fig_min_gray),int(255*fig_max_gray)))
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image)/255

      
    #print(x)
    return x

# %%
# generate a random number
def rand_interval(a = 0., b = 1.):
   rnd = a + (b-a)*np.random.random()
   return rnd

# %% [markdown]
# # **Random figure generator**

# %%
# Generator for random figures
# Each image contains exactly one object (circle, triangle, square)
def gen_n_figures(batch_size_gen=batch_size_gen, img_shape=img_shape):

        batch_events  = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        batch_targets =-np.ones((batch_size_gen, 1, 1 ))

        for n in range(batch_size_gen):
            
            k = np.random.randint(0,num_classes)

            
            rpix = rand_interval(rpix_min,rpix_max)
            r = rand_interval(img_cols*rmin, img_cols*rmax)
            d = rand_interval(img_cols*dmin, img_cols*dmax) 
            l = rand_interval(img_cols*dmin, img_cols*dmax)
            x0 = rand_interval(0.33*img_cols, 0.66*img_cols)       
            y0 = rand_interval(0.33*img_rows, 0.66*img_rows)     
            alpha = 360.*np.random.random()  

            if k == 0:
               batch_events[n,0] = generate_colon(rpix, x0, y0, alpha, img_shape)
            elif k == 1:
               batch_events[n,0] = generate_line(rpix, x0, y0, alpha, img_shape)  
            elif k == 2:                
               batch_events[n,0] = generate_circle(r, x0, y0, img_shape)
            elif k == 3:
               batch_events[n,0] = generate_square(d, x0, y0, alpha, img_shape)
            elif k == 4:
               batch_events[n,0] = generate_triangle(l, x0, y0, alpha, img_shape)                             
            else:
               print("Wrong figure id!!!")
            batch_targets[n,0] = k
            


        yield batch_events, batch_targets

# %% [markdown]
# # **Distort an image**
# Distortion might be either bluring or a conversion to jpeg and back.

# %%
# Distort images
from scipy import ndimage
#PILlow package
from PIL import Image
from io import BytesIO
import scipy.misc

def distort_n_figures(images, jpeg_compression, distortion=distortion, img_shape=img_shape, sigma = sigma):
  
  if (distortion == "blur"):
    images_distorted = np.zeros((len(images), 1, img_shape[0], img_shape[1]))
    for n in range(len(images)):
     
    
      images_distorted[n,0] = ndimage.gaussian_filter(255.*images[n,0], sigma=sigma)/255.
#      images_distorted[n,0] = images[n,0]

    return -1, images_distorted

  elif (distortion == "jpeg"):
    images_distorted = np.zeros((len(images), 1, img_shape[0], img_shape[1]))
    # create a BIG image just with noise
    array_big = next(gen_noise(1, bigIm_shape ))
    image_file_size = 0

    #n_big = len(images)

    for n in range(len(images)):
        # convert to jpeg and than back
        if  (n+1)%10000==0:
           print("Distorting image ",n)

        buffer = BytesIO()
        auxIm = Image.fromarray((255.*images[n,0]).astype(np.uint8))

        if n < n_big:
           #print("array_big.shape ",array_big[0,0].shape)
           bigIm = Image.fromarray((255.*array_big[0,0]).astype(np.uint8))
           #print("bigIm.size ",bigIm.size)
           #print("auxIm.size ",auxIm.size)
           #paste auxIm into the middle of bigIm
           bigIm.paste(auxIm,(smallIm_X,smallIm_Y))
           auxIm = bigIm
        #print("auxIm.size from bigIm ",auxIm.size)

        if jpeg_format == 'jpeg':
           auxIm.save(buffer, format=jpeg_format, quality=jpeg_compression)
        elif jpeg_format == 'JPEG2000':
           auxIm.save(buffer, format=jpeg_format, quality_mode='rates', quality_layers=jpeg_compression, irreversible=True)  
        else:
           print("Unknown format %s" % jpeg_format)    

        if n < n_big:
           image_file_size = image_file_size + buffer.tell()

  
        buffer.seek(0)
        auxIm = Image.open(buffer)

        # resize image and then resize back to the original size using BICUBIC
        if (extrapolation_factor != 1.):
           width, height = auxIm.size
           auxIm = auxIm.resize((int(extrapolation_factor*width),int(extrapolation_factor*height)),resample=Image.BICUBIC)
           #print("image size ",auxIm.size)
           auxIm = auxIm.resize((width,height),resample=Image.BICUBIC)
        
        # crop original image from the big image
        if n < n_big:
           auxIm = auxIm.crop((smallIm_X,smallIm_Y,smallIm_X+img_cols,smallIm_Y+img_rows))
        #print("Final image size ",auxIm.size)

        # add image to the array of distorted images
        images_distorted[n,0] = np.array(auxIm) / 255.  
 
    average_size = image_file_size/n_big

    return average_size, images_distorted

  else:
    return -1, images

# %% [markdown]
# ## **Plot some images**

# %%
def plot_images(plot_size=6):

  class_names = ['colon','line','circle','square','triangle']

  offset = max(0, min(batch_size_gen-plot_size*plot_size, np.random.randint(0,batch_size_gen/2)))
  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for n in range(min(plot_size*plot_size,len(xx_train))):
    ax = plt.subplot(plot_size, plot_size, n+1)
    ax.imshow(xx_train[n+offset,0], cmap='gray', vmin=0, vmax=1)
    ax.set_title(class_names[int(yy_train[n+offset,0])])
    ax.axis('off')

  plt.show()
  #plt.savefig('event.png')
  #plt.clf()


#plotting results of classification
def plot_results(plot_size=6):
  
  class_names = ['colon','line','circle','square','triangle']
  YY_pred = saved_model.predict(xx_val, verbose=2)
  
  offset = max(0, min(len(YY_pred)-plot_size*plot_size, np.random.randint(0,len(YY_pred)/2)))

  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for i in range(int(min(plot_size/2,len(YY_pred)/plot_size))):
    for n in range(int(min(plot_size,len(YY_pred)))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+n+1 )
      ax.imshow(xx_val[plot_size*i+n+offset,0], cmap='gray', vmin=0, vmax=1)
      ax.axis('off')

    for n in range(min(plot_size,len(YY_pred))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+plot_size+n+1)
      x = np.arange(num_classes)
      ax.bar(x, height = YY_pred[plot_size*i+n+offset,0], tick_label = class_names[0:num_classes]) 
      ax.axis('off')
#      ax.set_title(class_names[int(np.argmax(YY_pred,axis=2)[plot_size*i+n+offset])])
      ax.set_title(class_names[int(np.argmax(yy_val,axis=2)[plot_size*i+n+offset])])
#      print("yy_val",np.argmax(yy_val,axis=2))
#      print("YY_pred",np.argmax(YY_pred,axis=2))
  
  plt.show()
  #plt.savefig('event.png')
  #plt.clf()

# %% [markdown]
# # **Generate training and test data**

# %%
def generate_datasets():

   #generate training and validation dataset
   xx_train, yy_train = next(gen_n_figures(batch_size_gen, img_shape))
   xx_test, yy_test   = next(gen_n_figures(batch_size_val, img_shape))
   xx_val, yy_val     = next(gen_n_figures(batch_size_val, img_shape))

   print("Figures created")

   # add noise
   xx_train = xx_train + next(gen_noise(batch_size_gen, img_shape))
   xx_test  = xx_test  + next(gen_noise(batch_size_val, img_shape))
   xx_val   = xx_val  + next(gen_noise(batch_size_val, img_shape))

   print("Noise added")

   #and distort an image
   av_size_train, xx_train = distort_n_figures(xx_train, jpeg_compression)
   av_size_test, xx_test  = distort_n_figures(xx_test, jpeg_compression)
   av_size_val, xx_val   = distort_n_figures(xx_val, jpeg_compression)

   print("Images distorted")
   
   #and clip to get maximum 1
   xx_train = np.clip(xx_train, 0, 1)
   xx_test  = np.clip(xx_test, 0, 1)
   xx_val   = np.clip(xx_val, 0, 1)

 
   return xx_train, xx_test, xx_val, yy_train, yy_test, yy_val, av_size_train

# %% [markdown]
# # **Draw confussion matrix**

# %%
# Confusion matrix result

def draw_confussion_matrix():

   from sklearn.metrics import classification_report, confusion_matrix
   YY_pred = saved_model.predict(xx_val, verbose=2)
   yy_pred = np.argmax(YY_pred, axis=2)

   yy_test2 = np.argmax(yy_test, axis=2)



   #confusion matrix
   cm = confusion_matrix(np.argmax(yy_val,axis=2),yy_pred)
   print(cm)

   # Visualizing of confusion matrix
   import seaborn as sn
   import pandas  as pd


   df_cm = pd.DataFrame(cm, range(num_classes),range(num_classes))
   plt.figure(figsize = (10,7))
   sn.set(font_scale=1.4)#for label size
   sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
   plt.show()

# %% [markdown]
# # **Plot training results**

# %%
# Plots for training and testing process: loss and accuracy
def plot_training_results(cnn):

   n_epochs = len(cnn.history['loss'])

   plt.figure(0)
   plt.plot(cnn.history['categorical_accuracy'],'r')
   plt.plot(cnn.history['val_categorical_accuracy'],'g')
   plt.xticks(np.arange(0, n_epochs, 10.0))
   plt.rcParams['figure.figsize'] = (8, 6)
   plt.xlabel("Num of Epochs")
   plt.ylabel("Accuracy")
   plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
   plt.legend(['train','validation'])

   plt.figure(1)
   plt.plot(cnn.history['loss'],'r')
   plt.plot(cnn.history['val_loss'],'g')
   plt.xticks(np.arange(0, n_epochs, 10.0))
   plt.rcParams['figure.figsize'] = (8, 6)
   plt.xlabel("Num of Epochs")
   plt.ylabel("Loss")
   plt.title("Training Loss vs Validation Loss")
   plt.legend(['train','validation'])
   plt.show()

# %% [markdown]
# # **Define Deep Neural Network**

# %%
# Define Model

def base_model():

    model = Sequential()
    input_shape=(1,img_rows,img_cols)

    model.add(Reshape((img_rows,img_cols,1),input_shape=input_shape))


    model.add(Conv2D(img_rows, (3, 3), padding='same', activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(img_rows,(3,3),padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dropout(rate = 0.2))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))


    model.add(Dense(num_classes, activation='softmax'))

    model.add(Reshape((1,num_classes),input_shape=(num_classes,)))

#    sgd = SGD(lr = 0.1, decay=1e-6, nesterov=True)
#    sgd = SGD(lr = 0.01, decay=1e-6, nesterov=True)

# Compile model

    model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=[metrics.categorical_accuracy])   # 'accuracy'

    return model

# %% [markdown]
# # **Visualize the network**

# %%
# Vizualizing model structure
# Model summary (ascii)
cnn_n = base_model()

cnn_n.summary()

# Model printout (ascii)
sequential_model_to_ascii_printout(cnn_n)

# Plotting model in graphical mode
plot_model(cnn_n)   ###, to_file='model.png')  ###, show_shapes=True
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1, 2)              0
# =================================================================
# Total params: 3,436,258
# Trainable params: 3,436,258
# Non-trainable params: 0
# _________________________________________________________________
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####      1   32   32
#              Reshape     |   -------------------         0     0.0%
#                        #####     32   32    1
#               Conv2D    \|/  -------------------       320     0.0%
#                 relu   #####     32   32   32
#              Dropout    | || -------------------         0     0.0%
#                        #####     32   32   32
#               Conv2D    \|/  -------------------      9248     0.3%
#                 relu   #####     32   32   32
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####     16   16   32
#               Conv2D    \|/  -------------------     18496     0.5%
#                 relu   #####     16   16   64
#              Dropout    | || -------------------         0     0.0%
#                        #####     16   16   64
#               Conv2D    \|/  -------------------     36928     1.1%
#                 relu   #####     16   16   64
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      8    8   64
#               Conv2D    \|/  -------------------     73856     2.1%
#                 relu   #####      8    8  128
#              Dropout    | || -------------------         0     0.0%
#                        #####      8    8  128
#               Conv2D    \|/  -------------------    147584     4.3%
#                 relu   #####      8    8  128
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      4    4  128
#              Flatten   ||||| -------------------         0     0.0%
#                        #####        2048
#              Dropout    | || -------------------         0     0.0%
#                        #####        2048
#                Dense   XXXXX -------------------   2098176    61.1%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------   1049600    30.5%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------      2050     0.1%
#              softmax   #####           2
#              Reshape     |   -------------------         0     0.0%
#                        #####      1    2

# %% [markdown]
# # **Train DNN** and display results for various jpeg qualities given in jpeg_quality_list

# %%
#acc_scores = []
#loss_scores = []

outcome = []

# Loop over extrapolations
for extrapolation_factor in extrapolation_list:

 # Loop over jpeg qualities
 if jpeg_format == 'jpeg':
   compression_list = jpeg_compression_list
 else:
  compression_list = jpeg2000_compression_list

 for jpeg_compression in compression_list:

   print(" ")
   print(" ")
   print("Extrapolation factor = ",extrapolation_factor)
   print("JPEG compression = ",jpeg_compression)
   print(" ")
   print(" ")
 
   # Generate data
   xx_train, xx_test, xx_val, yy_train, yy_test, yy_val, av_size = generate_datasets()

   #plot 100 figures (random offset)

   plot_images(6)


   plot_images(2)



   yy_train = np_utils.to_categorical(yy_train, num_classes)
   yy_test = np_utils.to_categorical(yy_test, num_classes)
   yy_val = np_utils.to_categorical(yy_val, num_classes)

   print("yy_train ",yy_train.shape)

   #Define the network
   cnn_n = base_model()
   # load the previously saved model
   try:
      cnn_n = load_model('best_model.h5')
   except:
      print("No saved model, training a new one.") 

   # patient early stopping
   es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=10)
   mc = ModelCheckpoint('best_model.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

   # fit model
   cnn = cnn_n.fit(xx_train, yy_train, batch_size=batch_size, epochs=epochs, validation_data=(xx_test,yy_test),shuffle=True, callbacks=[es, mc], verbose=1)
   # load the saved model
   saved_model = load_model('best_model.h5')


   # evaluate loaded model
   scores_train = saved_model.evaluate(xx_train, yy_train, verbose=0)
   scores_test  = saved_model.evaluate(xx_test,  yy_test,  verbose=0)
   scores_val   = saved_model.evaluate(xx_val,   yy_val,   verbose=0)
   print("Accuracy Train: %.2f%% , Test: %.2f%% Val: %.2f%% " % (scores_train[1]*100, scores_test[1]*100, scores_val[1]*100))

   # add scores
#   acc_scores.append(scores_val[1]*100)
#   loss_scores.append(scores_val[0]*100)
   outcome_row = (extrapolation_factor, jpeg_compression, av_size, scores_val[1]*100, scores_val[0]*100)
   outcome.append(outcome_row)

   #Plot training results
   plot_training_results(cnn)
   # Confussion matrix result
   draw_confussion_matrix()

   # Plot classified images
   plot_results(6)


   plot_results(2)
   plot_results(2)
   plot_results(2)
# Out:
#
#
# Extrapolation factor =  0.5
# JPEG compression =  100
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# No saved model, training a new one.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60000/60000 [==============================] - 16s 274us/step - loss: 0.4401 - categorical_accuracy: 0.7604 - val_loss: 0.3286 - val_categorical_accuracy: 0.8425
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.84250, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3151 - categorical_accuracy: 0.8405 - val_loss: 0.2912 - val_categorical_accuracy: 0.8496
#
# Epoch 00002: val_categorical_accuracy improved from 0.84250 to 0.84960, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 13s 222us/step - loss: 0.3004 - categorical_accuracy: 0.8498 - val_loss: 0.2911 - val_categorical_accuracy: 0.8562
#
# Epoch 00003: val_categorical_accuracy improved from 0.84960 to 0.85620, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2903 - categorical_accuracy: 0.8552 - val_loss: 0.2749 - val_categorical_accuracy: 0.8632
#
# Epoch 00004: val_categorical_accuracy improved from 0.85620 to 0.86320, saving model to best_model.h5
# Epoch 5/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2849 - categorical_accuracy: 0.8574 - val_loss: 0.2752 - val_categorical_accuracy: 0.8569
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.86320
# Epoch 6/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2812 - categorical_accuracy: 0.8598 - val_loss: 0.2746 - val_categorical_accuracy: 0.8611
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.86320
# Epoch 7/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2812 - categorical_accuracy: 0.8583 - val_loss: 0.2758 - val_categorical_accuracy: 0.8635
#
# Epoch 00007: val_categorical_accuracy improved from 0.86320 to 0.86350, saving model to best_model.h5
# Epoch 8/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2732 - categorical_accuracy: 0.8626 - val_loss: 0.2697 - val_categorical_accuracy: 0.8643
#
# Epoch 00008: val_categorical_accuracy improved from 0.86350 to 0.86430, saving model to best_model.h5
# Epoch 9/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2732 - categorical_accuracy: 0.8626 - val_loss: 0.2784 - val_categorical_accuracy: 0.8611
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.86430
# Epoch 10/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2694 - categorical_accuracy: 0.8637 - val_loss: 0.2703 - val_categorical_accuracy: 0.8636
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.86430
# Epoch 11/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2666 - categorical_accuracy: 0.8653 - val_loss: 0.2647 - val_categorical_accuracy: 0.8647
#
# Epoch 00011: val_categorical_accuracy improved from 0.86430 to 0.86470, saving model to best_model.h5
# Epoch 12/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2638 - categorical_accuracy: 0.8662 - val_loss: 0.2739 - val_categorical_accuracy: 0.8643
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.86470
# Epoch 13/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2625 - categorical_accuracy: 0.8660 - val_loss: 0.2747 - val_categorical_accuracy: 0.8646
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.86470
# Epoch 14/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2614 - categorical_accuracy: 0.8669 - val_loss: 0.2687 - val_categorical_accuracy: 0.8622
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.86470
# Epoch 15/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2563 - categorical_accuracy: 0.8690 - val_loss: 0.2674 - val_categorical_accuracy: 0.8656
#
# Epoch 00015: val_categorical_accuracy improved from 0.86470 to 0.86560, saving model to best_model.h5
# Epoch 16/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2552 - categorical_accuracy: 0.8699 - val_loss: 0.2618 - val_categorical_accuracy: 0.8670
#
# Epoch 00016: val_categorical_accuracy improved from 0.86560 to 0.86700, saving model to best_model.h5
# Epoch 17/256
# 60000/60000 [==============================] - 14s 225us/step - loss: 0.2549 - categorical_accuracy: 0.8707 - val_loss: 0.2756 - val_categorical_accuracy: 0.8628
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.86700
# Epoch 18/256
# 60000/60000 [==============================] - 14s 225us/step - loss: 0.2496 - categorical_accuracy: 0.8723 - val_loss: 0.2618 - val_categorical_accuracy: 0.8647
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.86700
# Epoch 19/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2493 - categorical_accuracy: 0.8729 - val_loss: 0.2647 - val_categorical_accuracy: 0.8643
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.86700
# Epoch 20/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2466 - categorical_accuracy: 0.8729 - val_loss: 0.2788 - val_categorical_accuracy: 0.8607
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.86700
# Epoch 21/256
# 60000/60000 [==============================] - 13s 225us/step - loss: 0.2449 - categorical_accuracy: 0.8752 - val_loss: 0.2590 - val_categorical_accuracy: 0.8690
#
# Epoch 00021: val_categorical_accuracy improved from 0.86700 to 0.86900, saving model to best_model.h5
# Epoch 22/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2437 - categorical_accuracy: 0.8752 - val_loss: 0.2653 - val_categorical_accuracy: 0.8638
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.86900
# Epoch 23/256
# 60000/60000 [==============================] - 14s 225us/step - loss: 0.2412 - categorical_accuracy: 0.8766 - val_loss: 0.2618 - val_categorical_accuracy: 0.8672
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.86900
# Epoch 24/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2406 - categorical_accuracy: 0.8776 - val_loss: 0.2637 - val_categorical_accuracy: 0.8668
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.86900
# Epoch 25/256
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.2382 - categorical_accuracy: 0.8783 - val_loss: 0.2637 - val_categorical_accuracy: 0.8665
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.86900
# Epoch 26/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2356 - categorical_accuracy: 0.8788 - val_loss: 0.2706 - val_categorical_accuracy: 0.8622
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.86900
# Epoch 27/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2334 - categorical_accuracy: 0.8809 - val_loss: 0.2694 - val_categorical_accuracy: 0.8635
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.86900
# Epoch 28/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2315 - categorical_accuracy: 0.8809 - val_loss: 0.2766 - val_categorical_accuracy: 0.8612
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.86900
# Epoch 29/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2310 - categorical_accuracy: 0.8820 - val_loss: 0.2661 - val_categorical_accuracy: 0.8623
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.86900
# Epoch 30/256
# 60000/60000 [==============================] - 13s 225us/step - loss: 0.2286 - categorical_accuracy: 0.8830 - val_loss: 0.2781 - val_categorical_accuracy: 0.8677
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.86900
# Epoch 31/256
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.2263 - categorical_accuracy: 0.8841 - val_loss: 0.2895 - val_categorical_accuracy: 0.8613
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.86900
# Epoch 00031: early stopping
# Accuracy Train: 88.72% , Test: 86.90% Val: 86.25%
# [[4035  988]
#  [ 387 4590]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  90
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.2740 - categorical_accuracy: 0.8622 - val_loss: 0.2612 - val_categorical_accuracy: 0.8659
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.86590, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2697 - categorical_accuracy: 0.8622 - val_loss: 0.2668 - val_categorical_accuracy: 0.8605
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.86590
# Epoch 3/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2647 - categorical_accuracy: 0.8650 - val_loss: 0.2681 - val_categorical_accuracy: 0.8675
#
# Epoch 00003: val_categorical_accuracy improved from 0.86590 to 0.86750, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2597 - categorical_accuracy: 0.8685 - val_loss: 0.2642 - val_categorical_accuracy: 0.8681
#
# Epoch 00004: val_categorical_accuracy improved from 0.86750 to 0.86810, saving model to best_model.h5
# Epoch 5/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2582 - categorical_accuracy: 0.8669 - val_loss: 0.2635 - val_categorical_accuracy: 0.8620
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.86810
# Epoch 6/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2557 - categorical_accuracy: 0.8685 - val_loss: 0.2574 - val_categorical_accuracy: 0.8684
#
# Epoch 00006: val_categorical_accuracy improved from 0.86810 to 0.86840, saving model to best_model.h5
# Epoch 7/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2525 - categorical_accuracy: 0.8712 - val_loss: 0.2573 - val_categorical_accuracy: 0.8667
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.86840
# Epoch 8/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2520 - categorical_accuracy: 0.8704 - val_loss: 0.2572 - val_categorical_accuracy: 0.8671
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.86840
# Epoch 9/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2510 - categorical_accuracy: 0.8725 - val_loss: 0.2531 - val_categorical_accuracy: 0.8670
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.86840
# Epoch 10/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2452 - categorical_accuracy: 0.8733 - val_loss: 0.2575 - val_categorical_accuracy: 0.8691
#
# Epoch 00010: val_categorical_accuracy improved from 0.86840 to 0.86910, saving model to best_model.h5
# Epoch 11/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2462 - categorical_accuracy: 0.8743 - val_loss: 0.2539 - val_categorical_accuracy: 0.8667
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.86910
# Epoch 12/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2441 - categorical_accuracy: 0.8740 - val_loss: 0.2581 - val_categorical_accuracy: 0.8628
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.86910
# Epoch 13/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2402 - categorical_accuracy: 0.8760 - val_loss: 0.2700 - val_categorical_accuracy: 0.8637
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.86910
# Epoch 14/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2382 - categorical_accuracy: 0.8783 - val_loss: 0.2587 - val_categorical_accuracy: 0.8670
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.86910
# Epoch 15/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2363 - categorical_accuracy: 0.8775 - val_loss: 0.2592 - val_categorical_accuracy: 0.8669
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.86910
# Epoch 16/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2369 - categorical_accuracy: 0.8785 - val_loss: 0.2738 - val_categorical_accuracy: 0.8604
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.86910
# Epoch 17/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2339 - categorical_accuracy: 0.8802 - val_loss: 0.2608 - val_categorical_accuracy: 0.8682
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.86910
# Epoch 18/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2304 - categorical_accuracy: 0.8807 - val_loss: 0.2598 - val_categorical_accuracy: 0.8679
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.86910
# Epoch 19/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2305 - categorical_accuracy: 0.8815 - val_loss: 0.2606 - val_categorical_accuracy: 0.8674
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.86910
# Epoch 20/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2270 - categorical_accuracy: 0.8843 - val_loss: 0.2627 - val_categorical_accuracy: 0.8630
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.86910
# Epoch 00020: early stopping
# Accuracy Train: 88.22% , Test: 86.91% Val: 86.88%
# [[4012  972]
#  [ 340 4676]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  70
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 14s 240us/step - loss: 0.2686 - categorical_accuracy: 0.8655 - val_loss: 0.2528 - val_categorical_accuracy: 0.8656
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.86560, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2624 - categorical_accuracy: 0.8668 - val_loss: 0.2453 - val_categorical_accuracy: 0.8724
#
# Epoch 00002: val_categorical_accuracy improved from 0.86560 to 0.87240, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2576 - categorical_accuracy: 0.8694 - val_loss: 0.2515 - val_categorical_accuracy: 0.8674
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.87240
# Epoch 4/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2539 - categorical_accuracy: 0.8702 - val_loss: 0.2499 - val_categorical_accuracy: 0.8718
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.87240
# Epoch 5/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2501 - categorical_accuracy: 0.8716 - val_loss: 0.2495 - val_categorical_accuracy: 0.8728
#
# Epoch 00005: val_categorical_accuracy improved from 0.87240 to 0.87280, saving model to best_model.h5
# Epoch 6/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2481 - categorical_accuracy: 0.8732 - val_loss: 0.2489 - val_categorical_accuracy: 0.8710
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.87280
# Epoch 7/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2477 - categorical_accuracy: 0.8750 - val_loss: 0.2541 - val_categorical_accuracy: 0.8664
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.87280
# Epoch 8/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2453 - categorical_accuracy: 0.8746 - val_loss: 0.2506 - val_categorical_accuracy: 0.8718
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.87280
# Epoch 9/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2405 - categorical_accuracy: 0.8772 - val_loss: 0.2542 - val_categorical_accuracy: 0.8678
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.87280
# Epoch 10/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2415 - categorical_accuracy: 0.8766 - val_loss: 0.2544 - val_categorical_accuracy: 0.8659
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.87280
# Epoch 11/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2389 - categorical_accuracy: 0.8784 - val_loss: 0.2484 - val_categorical_accuracy: 0.8711
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.87280
# Epoch 12/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2376 - categorical_accuracy: 0.8775 - val_loss: 0.2482 - val_categorical_accuracy: 0.8721
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.87280
# Epoch 13/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2353 - categorical_accuracy: 0.8789 - val_loss: 0.2558 - val_categorical_accuracy: 0.8699
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.87280
# Epoch 14/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2321 - categorical_accuracy: 0.8814 - val_loss: 0.2640 - val_categorical_accuracy: 0.8694
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.87280
# Epoch 15/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2316 - categorical_accuracy: 0.8813 - val_loss: 0.2515 - val_categorical_accuracy: 0.8720
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.87280
# Epoch 00015: early stopping
# Accuracy Train: 88.20% , Test: 87.28% Val: 87.03%
# [[4046  958]
#  [ 339 4657]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  50
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 15s 245us/step - loss: 0.2698 - categorical_accuracy: 0.8642 - val_loss: 0.2671 - val_categorical_accuracy: 0.8704
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.87040, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2627 - categorical_accuracy: 0.8661 - val_loss: 0.2587 - val_categorical_accuracy: 0.8675
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.87040
# Epoch 3/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2575 - categorical_accuracy: 0.8696 - val_loss: 0.2572 - val_categorical_accuracy: 0.8706
#
# Epoch 00003: val_categorical_accuracy improved from 0.87040 to 0.87060, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2558 - categorical_accuracy: 0.8680 - val_loss: 0.2621 - val_categorical_accuracy: 0.8687
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.87060
# Epoch 5/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2522 - categorical_accuracy: 0.8717 - val_loss: 0.2550 - val_categorical_accuracy: 0.8690
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.87060
# Epoch 6/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2532 - categorical_accuracy: 0.8716 - val_loss: 0.2549 - val_categorical_accuracy: 0.8715
#
# Epoch 00006: val_categorical_accuracy improved from 0.87060 to 0.87150, saving model to best_model.h5
# Epoch 7/256
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.2464 - categorical_accuracy: 0.8739 - val_loss: 0.2526 - val_categorical_accuracy: 0.8725
#
# Epoch 00007: val_categorical_accuracy improved from 0.87150 to 0.87250, saving model to best_model.h5
# Epoch 8/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2476 - categorical_accuracy: 0.8739 - val_loss: 0.2544 - val_categorical_accuracy: 0.8693
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.87250
# Epoch 9/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2435 - categorical_accuracy: 0.8743 - val_loss: 0.2557 - val_categorical_accuracy: 0.8689
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.87250
# Epoch 10/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2431 - categorical_accuracy: 0.8753 - val_loss: 0.2591 - val_categorical_accuracy: 0.8677
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.87250
# Epoch 11/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2406 - categorical_accuracy: 0.8757 - val_loss: 0.2512 - val_categorical_accuracy: 0.8703
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.87250
# Epoch 12/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2406 - categorical_accuracy: 0.8752 - val_loss: 0.2570 - val_categorical_accuracy: 0.8706
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.87250
# Epoch 13/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2374 - categorical_accuracy: 0.8785 - val_loss: 0.2555 - val_categorical_accuracy: 0.8733
#
# Epoch 00013: val_categorical_accuracy improved from 0.87250 to 0.87330, saving model to best_model.h5
# Epoch 14/256
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.2349 - categorical_accuracy: 0.8800 - val_loss: 0.2601 - val_categorical_accuracy: 0.8699
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.87330
# Epoch 15/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2344 - categorical_accuracy: 0.8807 - val_loss: 0.2588 - val_categorical_accuracy: 0.8701
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.87330
# Epoch 16/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2313 - categorical_accuracy: 0.8808 - val_loss: 0.2662 - val_categorical_accuracy: 0.8697
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.87330
# Epoch 17/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2299 - categorical_accuracy: 0.8817 - val_loss: 0.2668 - val_categorical_accuracy: 0.8672
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.87330
# Epoch 18/256
# 60000/60000 [==============================] - 14s 227us/step - loss: 0.2280 - categorical_accuracy: 0.8840 - val_loss: 0.2573 - val_categorical_accuracy: 0.8699
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.87330
# Epoch 19/256
# 60000/60000 [==============================] - 15s 246us/step - loss: 0.2273 - categorical_accuracy: 0.8839 - val_loss: 0.2688 - val_categorical_accuracy: 0.8686
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.87330
# Epoch 20/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2238 - categorical_accuracy: 0.8850 - val_loss: 0.2833 - val_categorical_accuracy: 0.8697
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.87330
# Epoch 21/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2259 - categorical_accuracy: 0.8848 - val_loss: 0.2627 - val_categorical_accuracy: 0.8679
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.87330
# Epoch 22/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2245 - categorical_accuracy: 0.8843 - val_loss: 0.2588 - val_categorical_accuracy: 0.8677
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.87330
# Epoch 23/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2227 - categorical_accuracy: 0.8860 - val_loss: 0.2673 - val_categorical_accuracy: 0.8638
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.87330
# Epoch 00023: early stopping
# Accuracy Train: 89.17% , Test: 87.33% Val: 87.08%
# [[4293  671]
#  [ 621 4415]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  30
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 15s 249us/step - loss: 0.2746 - categorical_accuracy: 0.8618 - val_loss: 0.2534 - val_categorical_accuracy: 0.8719
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.87190, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2627 - categorical_accuracy: 0.8658 - val_loss: 0.2531 - val_categorical_accuracy: 0.8718
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.87190
# Epoch 3/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2632 - categorical_accuracy: 0.8664 - val_loss: 0.2576 - val_categorical_accuracy: 0.8718
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.87190
# Epoch 4/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2581 - categorical_accuracy: 0.8687 - val_loss: 0.2635 - val_categorical_accuracy: 0.8662
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.87190
# Epoch 5/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2559 - categorical_accuracy: 0.8684 - val_loss: 0.2521 - val_categorical_accuracy: 0.8708
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.87190
# Epoch 6/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2541 - categorical_accuracy: 0.8718 - val_loss: 0.2572 - val_categorical_accuracy: 0.8680
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.87190
# Epoch 7/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2515 - categorical_accuracy: 0.8701 - val_loss: 0.2540 - val_categorical_accuracy: 0.8712
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.87190
# Epoch 8/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2515 - categorical_accuracy: 0.8713 - val_loss: 0.2658 - val_categorical_accuracy: 0.8638
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.87190
# Epoch 9/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2476 - categorical_accuracy: 0.8726 - val_loss: 0.2559 - val_categorical_accuracy: 0.8689
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.87190
# Epoch 10/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2460 - categorical_accuracy: 0.8741 - val_loss: 0.2544 - val_categorical_accuracy: 0.8702
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.87190
# Epoch 11/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2470 - categorical_accuracy: 0.8749 - val_loss: 0.2667 - val_categorical_accuracy: 0.8669
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.87190
# Epoch 00011: early stopping
# Accuracy Train: 87.29% , Test: 87.19% Val: 86.89%
# [[4128  925]
#  [ 386 4561]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  10
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 15s 256us/step - loss: 0.2856 - categorical_accuracy: 0.8545 - val_loss: 0.2740 - val_categorical_accuracy: 0.8605
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.86050, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2794 - categorical_accuracy: 0.8578 - val_loss: 0.2644 - val_categorical_accuracy: 0.8647
#
# Epoch 00002: val_categorical_accuracy improved from 0.86050 to 0.86470, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.2754 - categorical_accuracy: 0.8581 - val_loss: 0.2770 - val_categorical_accuracy: 0.8605
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.86470
# Epoch 4/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2728 - categorical_accuracy: 0.8589 - val_loss: 0.2722 - val_categorical_accuracy: 0.8609
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.86470
# Epoch 5/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2693 - categorical_accuracy: 0.8619 - val_loss: 0.2659 - val_categorical_accuracy: 0.8631
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.86470
# Epoch 6/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2658 - categorical_accuracy: 0.8612 - val_loss: 0.2699 - val_categorical_accuracy: 0.8642
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.86470
# Epoch 7/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2631 - categorical_accuracy: 0.8639 - val_loss: 0.2698 - val_categorical_accuracy: 0.8583
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.86470
# Epoch 8/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2648 - categorical_accuracy: 0.8628 - val_loss: 0.2755 - val_categorical_accuracy: 0.8582
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.86470
# Epoch 9/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2596 - categorical_accuracy: 0.8673 - val_loss: 0.2625 - val_categorical_accuracy: 0.8654
#
# Epoch 00009: val_categorical_accuracy improved from 0.86470 to 0.86540, saving model to best_model.h5
# Epoch 10/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2616 - categorical_accuracy: 0.8649 - val_loss: 0.2768 - val_categorical_accuracy: 0.8552
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.86540
# Epoch 11/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2592 - categorical_accuracy: 0.8662 - val_loss: 0.2784 - val_categorical_accuracy: 0.8556
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.86540
# Epoch 12/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2576 - categorical_accuracy: 0.8673 - val_loss: 0.2629 - val_categorical_accuracy: 0.8614
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.86540
# Epoch 13/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2579 - categorical_accuracy: 0.8669 - val_loss: 0.2663 - val_categorical_accuracy: 0.8611
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.86540
# Epoch 14/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2533 - categorical_accuracy: 0.8686 - val_loss: 0.2750 - val_categorical_accuracy: 0.8598
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.86540
# Epoch 15/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2529 - categorical_accuracy: 0.8705 - val_loss: 0.2701 - val_categorical_accuracy: 0.8574
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.86540
# Epoch 16/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2525 - categorical_accuracy: 0.8712 - val_loss: 0.2932 - val_categorical_accuracy: 0.8511
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.86540
# Epoch 17/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2613 - categorical_accuracy: 0.8668 - val_loss: 0.2716 - val_categorical_accuracy: 0.8584
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.86540
# Epoch 18/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.2481 - categorical_accuracy: 0.8718 - val_loss: 0.2717 - val_categorical_accuracy: 0.8574
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.86540
# Epoch 19/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2463 - categorical_accuracy: 0.8733 - val_loss: 0.2698 - val_categorical_accuracy: 0.8607
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.86540
# Epoch 00019: early stopping
# Accuracy Train: 87.84% , Test: 86.54% Val: 85.56%
# [[4014  972]
#  [ 472 4542]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  5
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 16s 260us/step - loss: 0.3237 - categorical_accuracy: 0.8394 - val_loss: 0.3098 - val_categorical_accuracy: 0.8393
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.83930, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.3135 - categorical_accuracy: 0.8419 - val_loss: 0.3054 - val_categorical_accuracy: 0.8439
#
# Epoch 00002: val_categorical_accuracy improved from 0.83930 to 0.84390, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.3066 - categorical_accuracy: 0.8456 - val_loss: 0.3044 - val_categorical_accuracy: 0.8476
#
# Epoch 00003: val_categorical_accuracy improved from 0.84390 to 0.84760, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.3050 - categorical_accuracy: 0.8462 - val_loss: 0.3067 - val_categorical_accuracy: 0.8441
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.84760
# Epoch 5/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.3031 - categorical_accuracy: 0.8463 - val_loss: 0.3109 - val_categorical_accuracy: 0.8396
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.84760
# Epoch 6/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2999 - categorical_accuracy: 0.8489 - val_loss: 0.3029 - val_categorical_accuracy: 0.8441
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.84760
# Epoch 7/256
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2969 - categorical_accuracy: 0.8505 - val_loss: 0.3041 - val_categorical_accuracy: 0.8425
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.84760
# Epoch 8/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2949 - categorical_accuracy: 0.8517 - val_loss: 0.3061 - val_categorical_accuracy: 0.8440
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.84760
# Epoch 9/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2948 - categorical_accuracy: 0.8508 - val_loss: 0.3081 - val_categorical_accuracy: 0.8412
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.84760
# Epoch 10/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2915 - categorical_accuracy: 0.8506 - val_loss: 0.3130 - val_categorical_accuracy: 0.8409
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.84760
# Epoch 11/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2888 - categorical_accuracy: 0.8547 - val_loss: 0.3067 - val_categorical_accuracy: 0.8409
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.84760
# Epoch 12/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2899 - categorical_accuracy: 0.8537 - val_loss: 0.3060 - val_categorical_accuracy: 0.8435
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.84760
# Epoch 13/256
# 60000/60000 [==============================] - 14s 231us/step - loss: 0.2854 - categorical_accuracy: 0.8560 - val_loss: 0.3197 - val_categorical_accuracy: 0.8416
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.84760
# Epoch 00013: early stopping
# Accuracy Train: 85.53% , Test: 84.76% Val: 83.99%
# [[3976 1017]
#  [ 584 4423]]
#
#
# Extrapolation factor =  0.5
# JPEG compression =  1
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 16s 269us/step - loss: 0.4152 - categorical_accuracy: 0.7835 - val_loss: 0.3912 - val_categorical_accuracy: 0.7958
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.79580, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.4052 - categorical_accuracy: 0.7886 - val_loss: 0.3917 - val_categorical_accuracy: 0.7963
#
# Epoch 00002: val_categorical_accuracy improved from 0.79580 to 0.79630, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.4000 - categorical_accuracy: 0.7915 - val_loss: 0.3847 - val_categorical_accuracy: 0.7986
#
# Epoch 00003: val_categorical_accuracy improved from 0.79630 to 0.79860, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.3958 - categorical_accuracy: 0.7935 - val_loss: 0.3871 - val_categorical_accuracy: 0.7984
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.79860
# Epoch 5/256
# 60000/60000 [==============================] - 14s 237us/step - loss: 0.3922 - categorical_accuracy: 0.7957 - val_loss: 0.3949 - val_categorical_accuracy: 0.7896
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.79860
# Epoch 6/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.3920 - categorical_accuracy: 0.7948 - val_loss: 0.3991 - val_categorical_accuracy: 0.7971
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.79860
# Epoch 7/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.3888 - categorical_accuracy: 0.7952 - val_loss: 0.3963 - val_categorical_accuracy: 0.7935
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.79860
# Epoch 8/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.3855 - categorical_accuracy: 0.7990 - val_loss: 0.3869 - val_categorical_accuracy: 0.7969
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.79860
# Epoch 9/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.3844 - categorical_accuracy: 0.7970 - val_loss: 0.3958 - val_categorical_accuracy: 0.7966
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.79860
# Epoch 10/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.3807 - categorical_accuracy: 0.8007 - val_loss: 0.3923 - val_categorical_accuracy: 0.7948
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.79860
# Epoch 11/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.3801 - categorical_accuracy: 0.8011 - val_loss: 0.3923 - val_categorical_accuracy: 0.7952
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.79860
# Epoch 12/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.3767 - categorical_accuracy: 0.8033 - val_loss: 0.3905 - val_categorical_accuracy: 0.7961
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.79860
# Epoch 13/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.3743 - categorical_accuracy: 0.8037 - val_loss: 0.3938 - val_categorical_accuracy: 0.7928
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.79860
# Epoch 00013: early stopping
# Accuracy Train: 80.11% , Test: 79.86% Val: 78.95%
# [[3961  995]
#  [1110 3934]]
#
#
# Extrapolation factor =  1.0
# JPEG compression =  100
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.2608 - categorical_accuracy: 0.8669 - val_loss: 0.2343 - val_categorical_accuracy: 0.8826
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.88260, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2413 - categorical_accuracy: 0.8759 - val_loss: 0.2290 - val_categorical_accuracy: 0.8848
#
# Epoch 00002: val_categorical_accuracy improved from 0.88260 to 0.88480, saving model to best_model.h5
# Epoch 3/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2302 - categorical_accuracy: 0.8823 - val_loss: 0.2261 - val_categorical_accuracy: 0.8844
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.88480
# Epoch 4/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2260 - categorical_accuracy: 0.8837 - val_loss: 0.2243 - val_categorical_accuracy: 0.8861
#
# Epoch 00004: val_categorical_accuracy improved from 0.88480 to 0.88610, saving model to best_model.h5
# Epoch 5/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2208 - categorical_accuracy: 0.8861 - val_loss: 0.2190 - val_categorical_accuracy: 0.8889
#
# Epoch 00005: val_categorical_accuracy improved from 0.88610 to 0.88890, saving model to best_model.h5
# Epoch 6/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2153 - categorical_accuracy: 0.8892 - val_loss: 0.2224 - val_categorical_accuracy: 0.8846
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.88890
# Epoch 7/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.2164 - categorical_accuracy: 0.8888 - val_loss: 0.2207 - val_categorical_accuracy: 0.8894
#
# Epoch 00007: val_categorical_accuracy improved from 0.88890 to 0.88940, saving model to best_model.h5
# Epoch 8/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2106 - categorical_accuracy: 0.8918 - val_loss: 0.2174 - val_categorical_accuracy: 0.8895
#
# Epoch 00008: val_categorical_accuracy improved from 0.88940 to 0.88950, saving model to best_model.h5
# Epoch 9/256
# 60000/60000 [==============================] - 14s 238us/step - loss: 0.2119 - categorical_accuracy: 0.8919 - val_loss: 0.2238 - val_categorical_accuracy: 0.8865
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.88950
# Epoch 10/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2099 - categorical_accuracy: 0.8919 - val_loss: 0.2214 - val_categorical_accuracy: 0.8843
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.88950
# Epoch 11/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.2043 - categorical_accuracy: 0.8941 - val_loss: 0.2177 - val_categorical_accuracy: 0.8912
#
# Epoch 00011: val_categorical_accuracy improved from 0.88950 to 0.89120, saving model to best_model.h5
# Epoch 12/256
# 60000/60000 [==============================] - 14s 237us/step - loss: 0.2024 - categorical_accuracy: 0.8952 - val_loss: 0.2172 - val_categorical_accuracy: 0.8914
#
# Epoch 00012: val_categorical_accuracy improved from 0.89120 to 0.89140, saving model to best_model.h5
# Epoch 13/256
# 60000/60000 [==============================] - 14s 237us/step - loss: 0.2003 - categorical_accuracy: 0.8964 - val_loss: 0.2195 - val_categorical_accuracy: 0.8913
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.89140
# Epoch 14/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1992 - categorical_accuracy: 0.8974 - val_loss: 0.2169 - val_categorical_accuracy: 0.8887
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.89140
# Epoch 15/256
# 60000/60000 [==============================] - 14s 238us/step - loss: 0.1933 - categorical_accuracy: 0.9007 - val_loss: 0.2179 - val_categorical_accuracy: 0.8920
#
# Epoch 00015: val_categorical_accuracy improved from 0.89140 to 0.89200, saving model to best_model.h5
# Epoch 16/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1964 - categorical_accuracy: 0.8990 - val_loss: 0.2180 - val_categorical_accuracy: 0.8892
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.89200
# Epoch 17/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1922 - categorical_accuracy: 0.8999 - val_loss: 0.2223 - val_categorical_accuracy: 0.8910
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.89200
# Epoch 18/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1916 - categorical_accuracy: 0.9018 - val_loss: 0.2290 - val_categorical_accuracy: 0.8917
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.89200
# Epoch 19/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1971 - categorical_accuracy: 0.8983 - val_loss: 0.2184 - val_categorical_accuracy: 0.8923
#
# Epoch 00019: val_categorical_accuracy improved from 0.89200 to 0.89230, saving model to best_model.h5
# Epoch 20/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1932 - categorical_accuracy: 0.8999 - val_loss: 0.2171 - val_categorical_accuracy: 0.8900
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.89230
# Epoch 21/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1875 - categorical_accuracy: 0.9044 - val_loss: 0.2161 - val_categorical_accuracy: 0.8918
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.89230
# Epoch 22/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1881 - categorical_accuracy: 0.9017 - val_loss: 0.2225 - val_categorical_accuracy: 0.8952
#
# Epoch 00022: val_categorical_accuracy improved from 0.89230 to 0.89520, saving model to best_model.h5
# Epoch 23/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1855 - categorical_accuracy: 0.9037 - val_loss: 0.2210 - val_categorical_accuracy: 0.8921
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.89520
# Epoch 24/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1809 - categorical_accuracy: 0.9059 - val_loss: 0.2208 - val_categorical_accuracy: 0.8928
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.89520
# Epoch 25/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1821 - categorical_accuracy: 0.9070 - val_loss: 0.2210 - val_categorical_accuracy: 0.8913
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.89520
# Epoch 26/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1807 - categorical_accuracy: 0.9067 - val_loss: 0.2240 - val_categorical_accuracy: 0.8919
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.89520
# Epoch 27/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1822 - categorical_accuracy: 0.9072 - val_loss: 0.2188 - val_categorical_accuracy: 0.8922
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.89520
# Epoch 28/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1797 - categorical_accuracy: 0.9083 - val_loss: 0.2257 - val_categorical_accuracy: 0.8888
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.89520
# Epoch 29/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1889 - categorical_accuracy: 0.9043 - val_loss: 0.2188 - val_categorical_accuracy: 0.8940
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.89520
# Epoch 30/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.1799 - categorical_accuracy: 0.9080 - val_loss: 0.2220 - val_categorical_accuracy: 0.8963
#
# Epoch 00030: val_categorical_accuracy improved from 0.89520 to 0.89630, saving model to best_model.h5
# Epoch 31/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1778 - categorical_accuracy: 0.9096 - val_loss: 0.2182 - val_categorical_accuracy: 0.8938
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.89630
# Epoch 32/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1733 - categorical_accuracy: 0.9119 - val_loss: 0.2274 - val_categorical_accuracy: 0.8931
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.89630
# Epoch 33/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1747 - categorical_accuracy: 0.9118 - val_loss: 0.2206 - val_categorical_accuracy: 0.8910
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.89630
# Epoch 34/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.1721 - categorical_accuracy: 0.9137 - val_loss: 0.2277 - val_categorical_accuracy: 0.8938
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.89630
# Epoch 35/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.1733 - categorical_accuracy: 0.9125 - val_loss: 0.2241 - val_categorical_accuracy: 0.8926
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.89630
# Epoch 36/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1704 - categorical_accuracy: 0.9144 - val_loss: 0.2353 - val_categorical_accuracy: 0.8926
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.89630
# Epoch 37/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1699 - categorical_accuracy: 0.9153 - val_loss: 0.2339 - val_categorical_accuracy: 0.8953
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.89630
# Epoch 38/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1688 - categorical_accuracy: 0.9139 - val_loss: 0.2351 - val_categorical_accuracy: 0.8943
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.89630
# Epoch 39/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1678 - categorical_accuracy: 0.9152 - val_loss: 0.2236 - val_categorical_accuracy: 0.8961
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.89630
# Epoch 40/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1666 - categorical_accuracy: 0.9168 - val_loss: 0.2369 - val_categorical_accuracy: 0.8938
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.89630
# Epoch 00040: early stopping
# Accuracy Train: 92.66% , Test: 89.63% Val: 89.23%
# [[4467  551]
#  [ 526 4456]]
#
#
# Extrapolation factor =  1.0
# JPEG compression =  90
#
#
# Figures created
# Noise added
# Distorting image  0
# Distorting image  5000
# Distorting image  10000
# Distorting image  15000
# Distorting image  20000
# Distorting image  25000
# Distorting image  30000
# Distorting image  35000
# Distorting image  40000
# Distorting image  45000
# Distorting image  50000
# Distorting image  55000
# Distorting image  0
# Distorting image  5000
# Distorting image  0
# Distorting image  5000
# Images distorted
# yy_train  (60000, 1, 2)
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# 60000/60000 [==============================] - 16s 274us/step - loss: 0.2323 - categorical_accuracy: 0.8832 - val_loss: 0.2326 - val_categorical_accuracy: 0.8916
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.89160, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2251 - categorical_accuracy: 0.8863 - val_loss: 0.2231 - val_categorical_accuracy: 0.8865
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.89160
# Epoch 3/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.2177 - categorical_accuracy: 0.8875 - val_loss: 0.2205 - val_categorical_accuracy: 0.8885
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.89160
# Epoch 4/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2137 - categorical_accuracy: 0.8918 - val_loss: 0.2152 - val_categorical_accuracy: 0.8910
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.89160
# Epoch 5/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2119 - categorical_accuracy: 0.8925 - val_loss: 0.2195 - val_categorical_accuracy: 0.8904
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.89160
# Epoch 6/256
# 60000/60000 [==============================] - 14s 238us/step - loss: 0.2080 - categorical_accuracy: 0.8938 - val_loss: 0.2154 - val_categorical_accuracy: 0.8896
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.89160
# Epoch 7/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.2047 - categorical_accuracy: 0.8961 - val_loss: 0.2212 - val_categorical_accuracy: 0.8915
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.89160
# Epoch 8/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.2018 - categorical_accuracy: 0.8967 - val_loss: 0.2113 - val_categorical_accuracy: 0.8943
#
# Epoch 00008: val_categorical_accuracy improved from 0.89160 to 0.89430, saving model to best_model.h5
# Epoch 9/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.2063 - categorical_accuracy: 0.8961 - val_loss: 0.2179 - val_categorical_accuracy: 0.8922
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.89430
# Epoch 10/256
# 60000/60000 [==============================] - 14s 238us/step - loss: 0.2039 - categorical_accuracy: 0.8975 - val_loss: 0.2133 - val_categorical_accuracy: 0.8920
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.89430
# Epoch 11/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1966 - categorical_accuracy: 0.9000 - val_loss: 0.2145 - val_categorical_accuracy: 0.8915
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.89430
# Epoch 12/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1923 - categorical_accuracy: 0.9034 - val_loss: 0.2174 - val_categorical_accuracy: 0.8887
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.89430
# Epoch 13/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1931 - categorical_accuracy: 0.9021 - val_loss: 0.2176 - val_categorical_accuracy: 0.8905
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.89430
# Epoch 14/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1911 - categorical_accuracy: 0.9033 - val_loss: 0.2111 - val_categorical_accuracy: 0.8948
#
# Epoch 00014: val_categorical_accuracy improved from 0.89430 to 0.89480, saving model to best_model.h5
# Epoch 15/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1874 - categorical_accuracy: 0.9056 - val_loss: 0.2171 - val_categorical_accuracy: 0.8940
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.89480
# Epoch 16/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1884 - categorical_accuracy: 0.9041 - val_loss: 0.2156 - val_categorical_accuracy: 0.8922
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.89480
# Epoch 17/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1854 - categorical_accuracy: 0.9050 - val_loss: 0.2126 - val_categorical_accuracy: 0.8950
#
# Epoch 00017: val_categorical_accuracy improved from 0.89480 to 0.89500, saving model to best_model.h5
# Epoch 18/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1843 - categorical_accuracy: 0.9074 - val_loss: 0.2188 - val_categorical_accuracy: 0.8958
#
# Epoch 00018: val_categorical_accuracy improved from 0.89500 to 0.89580, saving model to best_model.h5
# Epoch 19/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1847 - categorical_accuracy: 0.9064 - val_loss: 0.2144 - val_categorical_accuracy: 0.8925
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.89580
# Epoch 20/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1824 - categorical_accuracy: 0.9099 - val_loss: 0.2198 - val_categorical_accuracy: 0.8963
#
# Epoch 00020: val_categorical_accuracy improved from 0.89580 to 0.89630, saving model to best_model.h5
# Epoch 21/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.1818 - categorical_accuracy: 0.9098 - val_loss: 0.2250 - val_categorical_accuracy: 0.8934
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.89630
# Epoch 22/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1800 - categorical_accuracy: 0.9106 - val_loss: 0.2183 - val_categorical_accuracy: 0.8932
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.89630
# Epoch 23/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1799 - categorical_accuracy: 0.9111 - val_loss: 0.2227 - val_categorical_accuracy: 0.8919
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.89630
# Epoch 24/256
# 60000/60000 [==============================] - 14s 236us/step - loss: 0.1775 - categorical_accuracy: 0.9124 - val_loss: 0.2179 - val_categorical_accuracy: 0.8962
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.89630
# Epoch 25/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1741 - categorical_accuracy: 0.9137 - val_loss: 0.2168 - val_categorical_accuracy: 0.8952
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.89630
# Epoch 26/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1729 - categorical_accuracy: 0.9144 - val_loss: 0.2231 - val_categorical_accuracy: 0.8891
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.89630
# Epoch 27/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1736 - categorical_accuracy: 0.9138 - val_loss: 0.2124 - val_categorical_accuracy: 0.8967
#
# Epoch 00027: val_categorical_accuracy improved from 0.89630 to 0.89670, saving model to best_model.h5
# Epoch 28/256
# 60000/60000 [==============================] - 14s 237us/step - loss: 0.1741 - categorical_accuracy: 0.9145 - val_loss: 0.2193 - val_categorical_accuracy: 0.8939
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.89670
# Epoch 29/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1685 - categorical_accuracy: 0.9161 - val_loss: 0.2269 - val_categorical_accuracy: 0.8981
#
# Epoch 00029: val_categorical_accuracy improved from 0.89670 to 0.89810, saving model to best_model.h5
# Epoch 30/256
# 60000/60000 [==============================] - 14s 235us/step - loss: 0.1711 - categorical_accuracy: 0.9162 - val_loss: 0.2202 - val_categorical_accuracy: 0.8976
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.89810
# Epoch 31/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1683 - categorical_accuracy: 0.9159 - val_loss: 0.2204 - val_categorical_accuracy: 0.8926
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.89810
# Epoch 32/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1724 - categorical_accuracy: 0.9165 - val_loss: 0.2260 - val_categorical_accuracy: 0.8939
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.89810
# Epoch 33/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1722 - categorical_accuracy: 0.9163 - val_loss: 0.2275 - val_categorical_accuracy: 0.8973
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.89810
# Epoch 34/256
# 60000/60000 [==============================] - 14s 233us/step - loss: 0.1878 - categorical_accuracy: 0.9086 - val_loss: 0.2204 - val_categorical_accuracy: 0.8946
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.89810
# Epoch 35/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1857 - categorical_accuracy: 0.9088 - val_loss: 0.2304 - val_categorical_accuracy: 0.8969
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.89810
# Epoch 36/256
# 60000/60000 [==============================] - 14s 234us/step - loss: 0.1786 - categorical_accuracy: 0.9130 - val_loss: 0.2158 - val_categorical_accuracy: 0.8990
#
# Epoch 00036: val_categorical_accuracy improved from 0.89810 to 0.89900, saving model to best_model.h5
# Epoch 37/256
#  6784/60000 [==>...........................] - ETA: 12s - loss: 0.1709 - categorical_accuracy: 0.9145Buffered data was truncated after reaching the output size limit.

# %% [markdown]
# # **Draw accuracy and loss vs. jpeg quality**

# %%
#plot accuracy

print(outcome)

poly=[]
compr=[]
size=[]
extrap_last = -9999
for row in range(0,len(outcome)):
   extrap = outcome[row][0]
   #print(row,outcome[row] )
   if row == 0:
     extrap_last = extrap
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2])
     print(compr, poly)
   elif extrap != extrap_last:
     line, = pyl.plot(compr, poly)
     pyl.plot(compr, poly,"o")
     print("plot ",extrap_last,compr, poly)
     label = "Extrap. = "+str(extrap_last)
     line.set_label(label)
     poly=[]
     compr=[]
     size=[]
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2])
     extrap_last = extrap
   elif row == len(outcome)-1:
     poly.append(outcome[row][3])
     compr.append(outcome[row][1]) 
     size.append(outcome[row][2]) 
     line, = pyl.plot(compr, poly)
     pyl.plot(compr, poly,"o")
     print("plot ",extrap_last,compr, poly)
     label = "Extrap. = "+str(extrap_last)
     line.set_label(label)          
   else:
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2])



pyl.legend() 

pyl.title("Accuracy")
auxText = ""
if (jpeg_format == "JPEG2000"):
   auxText == "JPEG200 compression"
elif (jpeg_format == "jpeg"):
   auxText == "jpeg quality"  
pyl.xlabel(auxText)
pyl.ylabel("Accuracy")
pyl.show()


#print("Accuracy: ", acc_scores)
#print("JPEG compression: ", compression_list)
# Out:
# [(0.5, 100, 356728.6, 86.25, 26.33419110298157), (0.5, 90, 170715.15, 86.88, 26.137488489151), (0.5, 70, 112181.24, 87.03, 26.014729044437406), (0.5, 50, 87250.63, 87.08, 25.50472680568695), (0.5, 30, 62653.26, 86.89, 25.281613945961002), (0.5, 10, 23496.25, 85.56, 27.803949831724168), (0.5, 5, 11424.33, 83.99, 30.772109961509702), (0.5, 1, 7237.97, 78.95, 39.58236071586609), (1.0, 100, 357084.41, 89.23, 22.17612034380436), (1.0, 90, 170312.93, 90.21000000000001, 20.55763027191162), (1.0, 70, 111671.42, 90.58, 20.17712069094181), (1.0, 50, 87421.45, 90.42, 20.432413180470466), (1.0, 30, 62744.16, 89.9, 20.990057156085967), (1.0, 10, 23624.71, 87.87, 24.55193412542343), (1.0, 5, 11729.99, 85.1, 29.325072216987607), (1.0, 1, 7155.04, 79.94, 39.329770135879514), (2.0, 100, 356539.96, 90.85, 20.489867693185808), (2.0, 90, 170756.1, 90.86, 18.696724377274514), (2.0, 70, 112053.31, 90.51, 20.048106484413147), (2.0, 50, 87518.53, 90.07, 20.276465940475465), (2.0, 30, 62505.78, 90.21000000000001, 20.149300082325937), (2.0, 10, 23490.56, 87.81, 24.382482719421386), (2.0, 5, 11455.25, 85.45, 29.310723657608033), (2.0, 1, 7208.19, 80.2, 38.80608852863312)]
# [100] [86.25]
# plot  0.5 [100, 90, 70, 50, 30, 10, 5, 1] [86.25, 86.88, 87.03, 87.08, 86.89, 85.56, 83.99, 78.95]
# plot  1.0 [100, 90, 70, 50, 30, 10, 5, 1] [89.23, 90.21000000000001, 90.58, 90.42, 89.9, 87.87, 85.1, 79.94]
# plot  2.0 [100, 90, 70, 50, 30, 10, 5, 1] [90.85, 90.86, 90.51, 90.07, 90.21000000000001, 87.81, 85.45, 80.2]

# %%
#plot accuracy

print(outcome)

poly=[]
compr=[]
size=[]
extrap_last = -9999
for row in range(0,len(outcome)):
   extrap = outcome[row][0]
   #print(row,outcome[row] )
   if row == 0:
     extrap_last = extrap
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2]/1024.)
     #print(size, poly)
   elif extrap != extrap_last:
     line, = pyl.plot(size, poly)
     pyl.plot(size, poly,"o")
     #print("plot ",extrap_last,size, poly)
     label = "Extrap. = "+str(extrap_last)
     line.set_label(label)
     poly=[]
     compr=[]
     size=[]
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2]/1024.)
     extrap_last = extrap
   elif row == len(outcome)-1:
     poly.append(outcome[row][3])
     compr.append(outcome[row][1]) 
     size.append(outcome[row][2]/1024.) 
     line, = pyl.plot(size, poly)
     pyl.plot(size, poly,"o")
     #print("plot ",extrap_last,size, poly)
     label = "Extrap. = "+str(extrap_last)
     line.set_label(label)          
   else:
     poly.append(outcome[row][3])
     compr.append(outcome[row][1])
     size.append(outcome[row][2]/1024.)



pyl.legend() 

pyl.title("Accuracy")
auxText = jpeg_format+" file size [kB]"
pyl.xlabel(auxText)
pyl.ylabel(auxText)
pyl.show()

print(size)
print(compr)
print(poly)
#print("Accuracy: ", acc_scores)
#print("JPEG compression: ", compression_list)
# Out:
# [(0.5, 100, 356728.6, 86.25, 26.33419110298157), (0.5, 90, 170715.15, 86.88, 26.137488489151), (0.5, 70, 112181.24, 87.03, 26.014729044437406), (0.5, 50, 87250.63, 87.08, 25.50472680568695), (0.5, 30, 62653.26, 86.89, 25.281613945961002), (0.5, 10, 23496.25, 85.56, 27.803949831724168), (0.5, 5, 11424.33, 83.99, 30.772109961509702), (0.5, 1, 7237.97, 78.95, 39.58236071586609), (1.0, 100, 357084.41, 89.23, 22.17612034380436), (1.0, 90, 170312.93, 90.21000000000001, 20.55763027191162), (1.0, 70, 111671.42, 90.58, 20.17712069094181), (1.0, 50, 87421.45, 90.42, 20.432413180470466), (1.0, 30, 62744.16, 89.9, 20.990057156085967), (1.0, 10, 23624.71, 87.87, 24.55193412542343), (1.0, 5, 11729.99, 85.1, 29.325072216987607), (1.0, 1, 7155.04, 79.94, 39.329770135879514), (2.0, 100, 356539.96, 90.85, 20.489867693185808), (2.0, 90, 170756.1, 90.86, 18.696724377274514), (2.0, 70, 112053.31, 90.51, 20.048106484413147), (2.0, 50, 87518.53, 90.07, 20.276465940475465), (2.0, 30, 62505.78, 90.21000000000001, 20.149300082325937), (2.0, 10, 23490.56, 87.81, 24.382482719421386), (2.0, 5, 11455.25, 85.45, 29.310723657608033), (2.0, 1, 7208.19, 80.2, 38.80608852863312)]
# [348.1835546875, 166.75400390625, 109.427060546875, 85.467314453125, 61.04080078125, 22.94, 11.186767578125, 7.039248046875]
# [100, 90, 70, 50, 30, 10, 5, 1]
# [90.85, 90.86, 90.51, 90.07, 90.21000000000001, 87.81, 85.45, 80.2]

# %%
#plot loss
#pyl.plot(jpeg_compression_list, loss_scores)
#pyl.plot(jpeg_compression_list, loss_scores,'o')
#pyl.title("Loss")
#pyl.xlabel("JPEG quality")
#pyl.ylabel("Loss")
#pyl.show()
